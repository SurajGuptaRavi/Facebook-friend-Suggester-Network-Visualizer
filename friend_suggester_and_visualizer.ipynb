# %% [markdown]
# # Facebook Friend Suggester & Facebook Network Visualizer

# %%
class User:
    def __init__(self,user_id,username,email,mobile):
        self.user_id = user_id
        self.username = username
        self.email = email
        self.mobile = mobile
        
    def get_user_data(self):
        return {'id':self.user_id,'name':self.username,'email':self.email,'mobile':self.mobile}
    
    def show_user_data(self):
        for key in self.get_user_data():
            print(f"{key} :- {self.get_user_data()[key]}")

class Facebook:
    def __init__(self):
        self.users = {}
        
    def connect_user(self,user1,user2):
        """It connects the 2 user objects"""
        if user1 not in self.users:
            self.users[user1] = []
            
        if user2 not in self.users:
            self.users[user2] = []
            
        self.users[user1].append(user2)
        self.users[user2].append(user1)
        
    def get_friends(self,user1):
        """It returns all the user's friend object as a list"""
        return self.users[user1]
    
    def show_details(self):
        """It shows the details of each user and their friends"""
        for each_person in self.users:
            print(f"{each_person.user_id}.{each_person.username}")
            for ef in self.users[each_person]:
                print(f"  -{ef.username}")
            print("\n")
                
            

    
    def suggest_friends(self,user1,current_user,friends=[]):
        friends += [current_user]
        
        if friends.count(current_user) >= 2:
            return friends
        
        visited_friend = []
        suggested_friends = []
        for each_friend in self.users[current_user]:
            if each_friend not in visited_friend:
                new_friends = self.suggest_friends(user1,each_friend,friends)
                                                   
            if new_friends is not None:
                for esf in new_friends:
                    if esf not in self.users[user1] and  esf not in suggested_friends and esf != user1:
                        suggested_friends.append(esf)
                        
                    if esf not in visited_friend:
                        visited_friend.append(esf)
                    
        return suggested_friends
    
    def suggest_for(self,user):
        """It calls the suggest_friends method for suggesting the friends"""
        print(f"Suggested frieds for={user.username}")
        return self.suggest_friends(user,user,[])
    
    def draw_network(self):
        """It creates the visulaization for  connected network"""
        elements = []
        for each_user in self.users:
            elements.append({'data':{'id':each_user.username,'label':each_user.username}})
        
            for each_friend in self.users[each_user]:
                elements.append({'data':{'source':each_user.username,'target':each_friend.username}})
        if elements is []:
            elements.append({'data':{'id':"No Connection Found",'label':"No Connection Found"}})
        return elements
                                                   
                                        
                                                   
        
#these are dummy details              
u1 = User(1,"Suraj Rajesh Gupta","SurajRajeshGupta@gmail.com",8795148960)
u2 = User(2,"Sumit Mohan Naik","SumitNaik@gmail.com",8390888127)
u3 = User(3,"Shreya Mishra","ShreyaMishra@gmail.com",9284161739)
u4 = User(4,"Nakshatra Navrat","NakshatraNavrat@gmail.com",8390887531)
u5 = User(5,"Dhiraj Mishra","DhirajMishra@gmail.com",9852862960)
u6 = User(6,"Dale Lobo","DaleLobo@gmail.com",9784888127)
u7 = User(7,"Surya Nemiwal","SuryaNemiwal@gmail.com",8979162960)
u8 = User(8,"Raj Kushwaha","RajKushwaha@gmail.com",9267888127)
u9 = User(9,"Adarsh Srivastav","AdarshSrivastav@gmail.com",8390888127)
u10 = User(10,"Divyesh Pawar","DivyeshPawar@gmail.com",8390888127)
u11 = User(11,"Vidisha Barot","VidishaBarot@gmail.com",8390999127)
u12 = User(12,"Abhay Dwiwedi","AbhayDwiwedi@gmail.com",9267888127)
u13 = User(13,"Shivam Mishra","ShivamMishra@gmail.com",8390888127)
u14 = User(14,"Aditya Singh","AdityaSingh@gmail.com",8390888127)
u15 = User(15,"Ambuj Mishra","AmbujMishra@gmail.com",8390999127)
u16 = User(16,"Gautam","Gautam@gmail.com",9267888127)
u17 = User(17,"Shruti Gupta","ShrutiGupta@gmail.com",8390888127)
u18 = User(18,"Nisar Shah","NisarShah@gmail.com",8390888127)
u19 = User(19,"Ruchi","Ruchi@gmail.com",8390999127)

fb = Facebook()
fb.connect_user(u1,u2)
fb.connect_user(u1,u3)
fb.connect_user(u1,u4)
fb.connect_user(u1,u5)
fb.connect_user(u1,u17)
fb.connect_user(u1,u16)
fb.connect_user(u1,u8)
fb.connect_user(u1,u6)
fb.connect_user(u1,u18)

fb.connect_user(u2,u4)
fb.connect_user(u2,u5)
fb.connect_user(u2,u18)
fb.connect_user(u2,u3)
fb.connect_user(u2,u16)
fb.connect_user(u2,u6)

fb.connect_user(u3,u4)
fb.connect_user(u3,u8)

fb.connect_user(u4,u10)
fb.connect_user(u4,u11)
fb.connect_user(u4,u16)

fb.connect_user(u17,u19)
fb.connect_user(u17,u16)
fb.connect_user(u17,u11)

fb.connect_user(u16,u19)
fb.connect_user(u16,u11)

fb.connect_user(u18,u10)
fb.connect_user(u18,u9)
fb.connect_user(u18,u5)
fb.connect_user(u18,u6)

fb.connect_user(u9,u10)

fb.connect_user(u5,u6)
fb.connect_user(u5,u14)

fb.connect_user(u14,u12)
fb.connect_user(u14,u13)

fb.connect_user(u13,u12)

fb.connect_user(u8,u7)
fb.connect_user(u8,u15)

fb.connect_user(u15,u7)



#if you want to see the suggested friend list for u6 then pass u6 object in the below method
x = fb.suggest_for(u6)
print(f"Total Friends={len(x)}")
for e in x:
    print('-',e.username)
# Out:
# Suggested frieds for=Dale Lobo
# Total Friends=14
# - Nakshatra Navrat
# - Shreya Mishra
# - Raj Kushwaha
# - Surya Nemiwal
# - Ambuj Mishra
# - Divyesh Pawar
# - Adarsh Srivastav
# - Aditya Singh
# - Abhay Dwiwedi
# - Shivam Mishra
# - Vidisha Barot
# - Shruti Gupta
# - Ruchi
# - Gautam

# %%
network = fb.draw_network()

# %%
network
# Out:
# [{'data': {'id': 'Suraj Rajesh Gupta', 'label': 'Suraj Rajesh Gupta'}},
#  {'data': {'source': 'Suraj Rajesh Gupta', 'target': 'Sumit Mohan Naik'}},
#  {'data': {'source': 'Suraj Rajesh Gupta', 'target': 'Shreya Mishra'}},
#  {'data': {'source': 'Suraj Rajesh Gupta', 'target': 'Nakshatra Navrat'}},
#  {'data': {'source': 'Suraj Rajesh Gupta', 'target': 'Dhiraj Mishra'}},
#  {'data': {'source': 'Suraj Rajesh Gupta', 'target': 'Shruti Gupta'}},
#  {'data': {'source': 'Suraj Rajesh Gupta', 'target': 'Gautam'}},
#  {'data': {'source': 'Suraj Rajesh Gupta', 'target': 'Raj Kushwaha'}},
#  {'data': {'source': 'Suraj Rajesh Gupta', 'target': 'Dale Lobo'}},
#  {'data': {'source': 'Suraj Rajesh Gupta', 'target': 'Nisar Shah'}},
#  {'data': {'id': 'Sumit Mohan Naik', 'label': 'Sumit Mohan Naik'}},
#  {'data': {'source': 'Sumit Mohan Naik', 'target': 'Suraj Rajesh Gupta'}},
#  {'data': {'source': 'Sumit Mohan Naik', 'target': 'Nakshatra Navrat'}},
#  {'data': {'source': 'Sumit Mohan Naik', 'target': 'Dhiraj Mishra'}},
#  {'data': {'source': 'Sumit Mohan Naik', 'target': 'Nisar Shah'}},
#  {'data': {'source': 'Sumit Mohan Naik', 'target': 'Shreya Mishra'}},
#  {'data': {'source': 'Sumit Mohan Naik', 'target': 'Gautam'}},
#  {'data': {'source': 'Sumit Mohan Naik', 'target': 'Dale Lobo'}},
#  {'data': {'id': 'Shreya Mishra', 'label': 'Shreya Mishra'}},
#  {'data': {'source': 'Shreya Mishra', 'target': 'Suraj Rajesh Gupta'}},
#  {'data': {'source': 'Shreya Mishra', 'target': 'Sumit Mohan Naik'}},
#  {'data': {'source': 'Shreya Mishra', 'target': 'Nakshatra Navrat'}},
#  {'data': {'source': 'Shreya Mishra', 'target': 'Raj Kushwaha'}},
#  {'data': {'id': 'Nakshatra Navrat', 'label': 'Nakshatra Navrat'}},
#  {'data': {'source': 'Nakshatra Navrat', 'target': 'Suraj Rajesh Gupta'}},
#  {'data': {'source': 'Nakshatra Navrat', 'target': 'Sumit Mohan Naik'}},
#  {'data': {'source': 'Nakshatra Navrat', 'target': 'Shreya Mishra'}},
#  {'data': {'source': 'Nakshatra Navrat', 'target': 'Divyesh Pawar'}},
#  {'data': {'source': 'Nakshatra Navrat', 'target': 'Vidisha Barot'}},
#  {'data': {'source': 'Nakshatra Navrat', 'target': 'Gautam'}},
#  {'data': {'id': 'Dhiraj Mishra', 'label': 'Dhiraj Mishra'}},
#  {'data': {'source': 'Dhiraj Mishra', 'target': 'Suraj Rajesh Gupta'}},
#  {'data': {'source': 'Dhiraj Mishra', 'target': 'Sumit Mohan Naik'}},
#  {'data': {'source': 'Dhiraj Mishra', 'target': 'Nisar Shah'}},
#  {'data': {'source': 'Dhiraj Mishra', 'target': 'Dale Lobo'}},
#  {'data': {'source': 'Dhiraj Mishra', 'target': 'Aditya Singh'}},
#  {'data': {'id': 'Shruti Gupta', 'label': 'Shruti Gupta'}},
#  {'data': {'source': 'Shruti Gupta', 'target': 'Suraj Rajesh Gupta'}},
#  {'data': {'source': 'Shruti Gupta', 'target': 'Ruchi'}},
#  {'data': {'source': 'Shruti Gupta', 'target': 'Gautam'}},
#  {'data': {'source': 'Shruti Gupta', 'target': 'Vidisha Barot'}},
#  {'data': {'id': 'Gautam', 'label': 'Gautam'}},
#  {'data': {'source': 'Gautam', 'target': 'Suraj Rajesh Gupta'}},
#  {'data': {'source': 'Gautam', 'target': 'Sumit Mohan Naik'}},
#  {'data': {'source': 'Gautam', 'target': 'Nakshatra Navrat'}},
#  {'data': {'source': 'Gautam', 'target': 'Shruti Gupta'}},
#  {'data': {'source': 'Gautam', 'target': 'Ruchi'}},
#  {'data': {'source': 'Gautam', 'target': 'Vidisha Barot'}},
#  {'data': {'id': 'Raj Kushwaha', 'label': 'Raj Kushwaha'}},
#  {'data': {'source': 'Raj Kushwaha', 'target': 'Suraj Rajesh Gupta'}},
#  {'data': {'source': 'Raj Kushwaha', 'target': 'Shreya Mishra'}},
#  {'data': {'source': 'Raj Kushwaha', 'target': 'Surya Nemiwal'}},
#  {'data': {'source': 'Raj Kushwaha', 'target': 'Ambuj Mishra'}},
#  {'data': {'id': 'Dale Lobo', 'label': 'Dale Lobo'}},
#  {'data': {'source': 'Dale Lobo', 'target': 'Suraj Rajesh Gupta'}},
#  {'data': {'source': 'Dale Lobo', 'target': 'Sumit Mohan Naik'}},
#  {'data': {'source': 'Dale Lobo', 'target': 'Nisar Shah'}},
#  {'data': {'source': 'Dale Lobo', 'target': 'Dhiraj Mishra'}},
#  {'data': {'id': 'Nisar Shah', 'label': 'Nisar Shah'}},
#  {'data': {'source': 'Nisar Shah', 'target': 'Suraj Rajesh Gupta'}},
#  {'data': {'source': 'Nisar Shah', 'target': 'Sumit Mohan Naik'}},
#  {'data': {'source': 'Nisar Shah', 'target': 'Divyesh Pawar'}},
#  {'data': {'source': 'Nisar Shah', 'target': 'Adarsh Srivastav'}},
#  {'data': {'source': 'Nisar Shah', 'target': 'Dhiraj Mishra'}},
#  {'data': {'source': 'Nisar Shah', 'target': 'Dale Lobo'}},
#  {'data': {'id': 'Divyesh Pawar', 'label': 'Divyesh Pawar'}},
#  {'data': {'source': 'Divyesh Pawar', 'target': 'Nakshatra Navrat'}},
#  {'data': {'source': 'Divyesh Pawar', 'target': 'Nisar Shah'}},
#  {'data': {'source': 'Divyesh Pawar', 'target': 'Adarsh Srivastav'}},
#  {'data': {'id': 'Vidisha Barot', 'label': 'Vidisha Barot'}},
#  {'data': {'source': 'Vidisha Barot', 'target': 'Nakshatra Navrat'}},
#  {'data': {'source': 'Vidisha Barot', 'target': 'Shruti Gupta'}},
#  {'data': {'source': 'Vidisha Barot', 'target': 'Gautam'}},
#  {'data': {'id': 'Ruchi', 'label': 'Ruchi'}},
#  {'data': {'source': 'Ruchi', 'target': 'Shruti Gupta'}},
#  {'data': {'source': 'Ruchi', 'target': 'Gautam'}},
#  {'data': {'id': 'Adarsh Srivastav', 'label': 'Adarsh Srivastav'}},
#  {'data': {'source': 'Adarsh Srivastav', 'target': 'Nisar Shah'}},
#  {'data': {'source': 'Adarsh Srivastav', 'target': 'Divyesh Pawar'}},
#  {'data': {'id': 'Aditya Singh', 'label': 'Aditya Singh'}},
#  {'data': {'source': 'Aditya Singh', 'target': 'Dhiraj Mishra'}},
#  {'data': {'source': 'Aditya Singh', 'target': 'Abhay Dwiwedi'}},
#  {'data': {'source': 'Aditya Singh', 'target': 'Shivam Mishra'}},
#  {'data': {'id': 'Abhay Dwiwedi', 'label': 'Abhay Dwiwedi'}},
#  {'data': {'source': 'Abhay Dwiwedi', 'target': 'Aditya Singh'}},
#  {'data': {'source': 'Abhay Dwiwedi', 'target': 'Shivam Mishra'}},
#  {'data': {'id': 'Shivam Mishra', 'label': 'Shivam Mishra'}},
#  {'data': {'source': 'Shivam Mishra', 'target': 'Aditya Singh'}},
#  {'data': {'source': 'Shivam Mishra', 'target': 'Abhay Dwiwedi'}},
#  {'data': {'id': 'Surya Nemiwal', 'label': 'Surya Nemiwal'}},
#  {'data': {'source': 'Surya Nemiwal', 'target': 'Raj Kushwaha'}},
#  {'data': {'source': 'Surya Nemiwal', 'target': 'Ambuj Mishra'}},
#  {'data': {'id': 'Ambuj Mishra', 'label': 'Ambuj Mishra'}},
#  {'data': {'source': 'Ambuj Mishra', 'target': 'Raj Kushwaha'}},
#  {'data': {'source': 'Ambuj Mishra', 'target': 'Surya Nemiwal'}}]

# %% [markdown]
# ### Dash App

# %% [markdown]
# plz Install essential libraries for running the dash app in your system do google for guidance

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import dash_cytoscape as cyto
from dash.dependencies import Input, Output
import plotly.express as px

app = dash.Dash()

app.layout = html.Div([
    html.P("Facebook Network:"),
    cyto.Cytoscape(
        id='cytoscape',
        elements=network,#provide your network here
        layout={'name': 'breadthfirst'},
        style={'width': '1500px', 'height': '1000px'},#put resolution according to your screen
    )
])

app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [19/Dec/2020 12:47:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [19/Dec/2020 12:47:58] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [19/Dec/2020 12:47:58] "GET /_dash-dependencies HTTP/1.1" 200 -

# %% [markdown]
# ### Visualization:-

# %% [markdown]
# ![image.png](attachment:image.png)
